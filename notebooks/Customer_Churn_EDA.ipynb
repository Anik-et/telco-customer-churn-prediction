# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


class ModelTrainer:

    def __init__(self, config, X_train, y_train, X_test, y_test):

        self.config = config
        self.name = name 
        self.version = version
        self.X_train = X_train
        self.y_train = y_train

        self.X_test = X_test
        self.y_test = y_test

        self.model = None

    def create_model(self):

        self.model = RandomForestClassifier(
            n_estimators=self.config["model"]["n_estimators"],
            random_state=self.config["model"]["random_state"]
        )

    def train(self):

        self.model.fit(
            self.X_train,
            self.y_train
        )

    def predict(self):

        y_pred = self.model.predict(
            self.X_test
        )

        return y_pred

    def evaluate(self):

        y_pred = self.predict()

        accuracy = accuracy_score(
            self.y_test,
            y_pred
        )

        return accuracy

# %%
trainer1 = ModelTrainer(config)
trainer2 = ModelTrainer(config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 trainer1 = ModelTrainer(config)
#       2 trainer2 = ModelTrainer(config)
#
# NameError: name 'config' is not defined

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

print(rf.__dict__)
# Out:
# {'estimator': DecisionTreeClassifier(), 'n_estimators': 100, 'estimator_params': ('criterion', 'max_depth', 'min_samples_split', 'min_samples_leaf', 'min_weight_fraction_leaf', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'random_state', 'ccp_alpha', 'monotonic_cst'), 'bootstrap': True, 'oob_score': False, 'n_jobs': None, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'class_weight': None, 'max_samples': None, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'monotonic_cst': None, 'ccp_alpha': 0.0}

# %%
trainer = ModelTrainer(
    config,
    X_train,
    y_train,
    X_test,
    y_test
)

trainer.create_model()

trainer.train()

accuracy = trainer.evaluate()

print(accuracy)

# %%
class Model:

    def __init__(self, name, version):

        self.name = name
        self.version = version

    def show_info(self):

        print(f"Model: {self.name}, Version: {self.version}")

model1 = Model("Random Forest", "v1")

model2 = Model("XGBoost", "v2")

# %%
model1.show_info()
model2.show_info()
# Out:
# Model: Random Forest, Version: v1
# Model: XGBoost, Version: v2

# %%
kaggle datasets list -s "telco customer churn"
# Out:
#   Cell In[2], line 1
#     kaggle datasets list -s "telco customer churn"
#            ^
# SyntaxError: invalid syntax
